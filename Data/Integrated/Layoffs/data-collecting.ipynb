# %%
import pandas as pd

# %%
data = pd.read_csv("../../raw/layoffs.csv")
data.head()
# Out:
# Running cells with 'Python 3.11.5' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/DELL/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
data.country.unique()
# Out:
# <StringArray>
# [           'Australia',        'United States',              'Nigeria',
#                 'India',               'Brazil',       'United States.',
#                'France',              'Germany',               'Israel',
#                'Sweden',       'United Kingdom',                'Japan',
#           'South Korea',                'China',                'Italy',
#             'Singapore',            'Indonesia',              'Estonia',
#                'Canada',              'Ireland',              'Finland',
#           'Netherlands',                'Spain',             'Portugal',
#                 'Chile',             'Colombia',            'Argentina',
#            'Seychelles',              'Austria',               'Mexico',
#           'Switzerland',                'Egypt',                'Kenya',
#            'Luxembourg',               'Greece',               'Poland',
#                'Norway',              'Belgium',              'Denmark',
# ...

# %%
USA_data = data[data["country"] == "United States"]
USA_data.head()
# Out:
#          company       location        industry  total_laid_off  \
# 1       SiriusXM  New York City           Media           475.0
# 5  Embark Trucks    SF Bay Area  Transportation           230.0
# 7    UserTesting    SF Bay Area       Marketing            63.0
# 8         Airbnb    SF Bay Area             NaN            30.0
# 9       Accolade        Seattle      Healthcare             NaN
#
#    percentage_laid_off      date     stage        country  \
# 1                 0.08  3/6/2023  Post-IPO  United States
# 5                 0.70  3/3/2023  Post-IPO  United States
# 7                  NaN  3/3/2023  Acquired  United States
# 8                  NaN  3/3/2023  Post-IPO  United States
# 9                  NaN  3/3/2023  Post-IPO  United States
#
#    funds_raised_millions
# 1                  525.0
# 5                  317.0
# 7                  152.0
# 8                 6400.0
# 9                  458.0

# %%
USA_data.to_csv("Layoffs_USA.csv", index=False)
